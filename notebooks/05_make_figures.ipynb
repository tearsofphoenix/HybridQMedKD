# %% [markdown]
# # 05 - Make Figures
# Generate all paper figures from saved results.

# %%
import sys; sys.path.insert(0, '..')
from src.analysis.aggregate_results import build_summary_from_csvs, save_summary
from src.analysis.plot_results import (
    load_summary, plot_main_comparison,
    plot_performance_cost, plot_roc_placeholder)
exp_names = ['student_classic','student_classic_kd',
             'student_hybrid_nokd','student_hybrid_kd']
summary = build_summary_from_csvs(exp_names)
save_summary(summary)
plot_main_comparison(summary)
plot_performance_cost(summary)
plot_roc_placeholder()
# Out:
# Summary saved to outputs/tables/summary.json
# Saved: outputs/figures/main_comparison.png
# Saved: outputs/figures/performance_cost.png
# /Users/isaac/clawd/research/HybridQMedKD/notebooks/../src/analysis/plot_results.py:106: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=9)
# Saved: outputs/figures/roc_curves.png
# /Users/isaac/clawd/research/HybridQMedKD/notebooks/../src/analysis/plot_results.py:50: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=9)
