# %% [markdown]
# # 01 - Data Profiling
# Explore the WDBC dataset: class distribution, feature statistics, correlation.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/raw/wdbc.csv')
print(df.shape)
print(df['Diagnosis'].value_counts())
df.describe()
